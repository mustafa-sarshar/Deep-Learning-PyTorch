# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
from torch import nn

plt.rcParams["figure.figsize"] = (20, 9)

# %%
dataset_address = "../datasets/inertial-measurement-units/"
filename = "leg_extension_concentric_eccentric-000_00B46E19.csv"
df = pd.read_csv(dataset_address+filename, sep=",")

# %%
df["Acc_Mag"] = np.linalg.norm(df.loc[:, ["Acc_X", "Acc_Y", "Acc_Z"]], axis=1)
df["FreeAcc_Mag"] = np.linalg.norm(df.loc[:, ["FreeAcc_E", "FreeAcc_N", "FreeAcc_U"]], axis=1)
df["Gyr_Mag"] = np.linalg.norm(df.loc[:, ["Gyr_X", "Gyr_Y", "Gyr_Z"]], axis=1)
df["Mag_Mag"] = np.linalg.norm(df.loc[:, ["Mag_X", "Mag_Y", "Mag_Z"]], axis=1)
df.head()
# Out:
#    PacketCounter     Acc_X     Acc_Y     Acc_Z  FreeAcc_E  FreeAcc_N  \
# 0          54437  9.448204  2.795508 -1.087186   0.008175   0.019923
# 1          54438  9.447801  2.780835 -1.105421  -0.004995  -0.000485
# 2          54439  9.437092  2.749807 -1.108972  -0.032798  -0.009378
# 3          54440  9.424642  2.792023 -1.111783   0.009444  -0.007472
# 4          54441  9.391788  2.768613 -1.122069  -0.003644  -0.023771
#
#    FreeAcc_U     Gyr_X     Gyr_Y     Gyr_Z  ...  Mat[1][2]  Mat[2][2]  \
# 0   0.100180  0.003596  0.000356 -0.014000  ...   0.949130   0.142087
# 1   0.097707  0.000983  0.003595 -0.016615  ...   0.949080   0.142109
# 2   0.079168  0.000727  0.001008 -0.020384  ...   0.949018   0.142119
# 3   0.079491 -0.006627  0.001274 -0.016371  ...   0.948978   0.142066
# 4   0.042736 -0.004446 -0.000165 -0.018009  ...   0.948930   0.142035
#
#    Mat[3][2]  Mat[1][3]  Mat[2][3]  Mat[3][3]   Acc_Mag  FreeAcc_Mag  \
# 0   0.281005  -0.114741   0.987111  -0.111567  9.912890     0.102468
# 1   0.281162  -0.114761   0.987112  -0.111535  9.910396     0.097836
# 2   0.281365  -0.114751   0.987111  -0.111550  9.891914     0.086205
# 3   0.281529  -0.114692   0.987122  -0.111520  9.892185     0.080398
# 4   0.281705  -0.114650   0.987128  -0.111509  9.855452     0.049038
#
#     Gyr_Mag   Mag_Mag
# 0  0.014459  0.781878
# 1  0.017028  0.788375
# 2  0.020422  0.787488
# 3  0.017707  0.790506
# 4  0.018550  0.782766
#
# [5 rows x 40 columns]

# %%
cols_X = ["Acc_X", "Acc_Y", "Acc_Z"] + ["FreeAcc_E", "FreeAcc_N", "FreeAcc_U"] + ["Gyr_X", "Gyr_Y", "Gyr_Z"] + ["Mag_X", "Mag_Y", "Mag_Z"]
cols_y = ["Acc_Mag", "FreeAcc_Mag", "Gyr_Mag", "Mag_Mag"]
data_X = df.loc[:, cols_X].values
data_y = df.loc[:, cols_y].values

# %%
# specify sizes of the partitions
# order is train, dev, test
partitions = [.7, .2, .1]

# split the data (note the third input, and the TMP in the variable name)
train_data, testdev_data, train_labels, testdev_label = train_test_split(data_X, data_y, train_size=partitions[0])

# now split the testdev_data
split = partitions[1] / np.sum(partitions[1:])
dev_data, test_data, dev_labels, test_labels = train_test_split(testdev_data, testdev_label, train_size=split)

# %%
def create_model(n_input=1, n_output=1, lr=.01):
    model = nn.Sequential(
        nn.Linear(n_input, n_input*5),
        nn.ReLU(),
        nn.Linear(n_input*5, n_input*10),
        nn.ReLU(),
        nn.Linear(n_input*10, n_input*5),
        nn.ReLU(), 
        nn.Linear(n_input*5, n_output)
    )

    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    return model, optimizer

def train_model(X, y, X_dev, y_dev, model=None, loss_func=nn.MSELoss(), optimizer=None, n_epochs=1, plot_history=False):
    X = torch.Tensor(X).float()
    y = torch.Tensor(y).float()
    X_dev = torch.Tensor(X_dev).float()
    y_dev = torch.Tensor(y_dev).float()
    
    losses = torch.zeros(n_epochs)
    losses_dev = torch.zeros(n_epochs)

    ## Train the model!
    for i in range(n_epochs):

        # forward pass
        preds = model(X)
        preds_dev = model(X_dev)

        # compute loss (trainset)
        loss = loss_func(preds, y)
        losses[i] = loss
        
        # compute loss (dev)
        loss_dev = loss_func(preds_dev, y_dev)
        losses_dev[i] = loss_dev

        # backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if plot_history:
        plt.plot(losses.detach(), label="Loss (trainset)")
        plt.plot(losses_dev.detach(), label="Loss (dev)")
        plt.ylabel("Loss")
        plt.xlabel("Epochs")
        plt.title(f"Final Loss (trainset): {loss.detach():.4f}\nFinal Loss (dev): {loss_dev.detach():.4f}")
        plt.legend()
        plt.show()
    return losses

def evaluate_model(X, y, model):
    X = torch.Tensor(X).float()
    y = torch.Tensor(y).float()

    # final forward pass
    predictions = model(X)

    # final loss (MSE)
    test_loss = (predictions-y).pow(2).mean()

    # correlation between the predictions and the ground truth
    r = np.corrcoef(y.T, predictions.detach().T)
    r_mean = np.mean(r[np.triu_indices(r.shape[1], k=1)])

    COLORS = "bgrmykc"
    for feature_i in range(y.shape[1]):
        for sample_i in range(y.shape[0]):
            plt.scatter(sample_i, y[sample_i, feature_i], color=COLORS[feature_i], alpha=.5, linewidths=.5)
            plt.scatter(sample_i, predictions.detach()[sample_i, feature_i], color=COLORS[feature_i], alpha=.5, linewidths=1, marker="x")
    plt.legend(["Ground Truth", "Prediction"])
    plt.xlabel("Samples")
    plt.ylabel("Values")    
    plt.title(f"Avg. correleration between prediction and ground truth r={r_mean:.2f}\nFinal loss = {test_loss.item():.4f}")
    plt.show()
        
    return test_loss, r, r_mean, predictions

# %%
model, optimizer = create_model(n_input=len(cols_X), n_output=len(cols_y), lr=.01)
history = train_model(
    X=train_data, y=train_labels, X_dev=dev_data, y_dev=dev_labels,
    model=model, loss_func=nn.MSELoss(), optimizer=optimizer, n_epochs=1000,
    plot_history=True
)

# %%
test_loss, r, r_mean, preds = evaluate_model(X=test_data, y=test_labels, model=model)
print(f"Test Loss: {test_loss:.4f}")
print(f"Avg. correleration between prediction and ground truth: {r_mean:.4f}")
# Out:
# Test Loss: 0.0239
# Avg. correleration between prediction and ground truth: 0.7177
